# %% [markdown]
# Importing  Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib  import pyplot as plt
import seaborn as sb

# %% [markdown]
# Extracting the data from file

# %%
diamonds=pd.read_csv("diamonds.csv")
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# deleting the unwanted column

# %%
diamonds2=diamonds.drop("Unnamed: 0",axis=1)
diamonds2.shape
# Out:
# (53940, 10)

# %% [markdown]
# To check the what type of information has dataset.

# %%
diamonds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# To check if any null value or empty cells in the data.

# %%
diamonds2.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# To see the  statisticall data means average and min and max values

# %%
diamonds2.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# The min value of x,y,z is 0 means no height, length of the that diamond so it's not possible so we can deleteing that rows

# %%
diamonds2.loc[(diamonds2['x']==0) | (diamonds2['y']==0) | (diamonds2['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
diamonds2 = diamonds2[(diamonds2[['x','y','z']] != 0).all(axis=1)]

# %% [markdown]
# To check if any duplicated values are there or not.

# %%
result=diamonds2.duplicated()
result.sum()
#diamonds2[result]
# Out:
# 145

# %% [markdown]
# so 145 dummy rows are there we can seee that rows are true ao false

# %%
diamonds2[result]
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 1005    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1006    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1007    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1008    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 2025    1.52   Good     E      I1   57.3   58.0   3105  7.53  7.42  4.28
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 47296   0.30   Good     J     VS1   63.4   57.0    394  4.23  4.26  2.69
# 47969   0.52  Ideal     D     VS2   61.8   55.0   1919  5.19  5.16  3.20
# 49326   0.51  Ideal     F    VVS2   61.2   56.0   2093  5.17  5.19  3.17
# 50079   0.51  Ideal     F    VVS2   61.2   56.0   2203  5.19  5.17  3.17
# 52861   0.50   Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
#
# [145 rows x 10 columns]

# %% [markdown]
# To delet the duplicate rows

# %%
diamonds2.drop_duplicates(inplace=True)

# %% [markdown]
# Now the dataset is ready to do calculations and geting the insight it

# %%
diamonds2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53775 rows x 10 columns]

# %% [markdown]
# To scaling of all features

# %%
sb.boxplot(diamonds2.price)
plt.show()
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
q1 = diamonds2['price'].quantile(0.25)                 
q3 = diamonds2['price'].quantile(0.75)
iqr = q3 - q1

# %%
filter = (diamonds2['price'] >= q1 - iqr*1.5) & (diamonds2['price'] <= q3 + 1.5*iqr)
diamonds2.loc[filter]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [50255 rows x 10 columns]

# %% [markdown]
# To check which cut have more times comes

# %%
sb.histplot(diamonds2.cut)
plt.show()

# %%
sb.kdeplot(diamonds2['carat'], shade=True , color='b')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
sb.jointplot(x='carat' , y='price' , data=diamonds2 , size=5)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# So there is a relation ship between carat and price. if carat size increase the price also increased

# %% [markdown]
# To plot the which color has highest %

# %%
diamonds2.color.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# our pridection is on price variable so we can check the statisticall information

# %%
diamonds2.price.describe()
# Out:
# count    53775.000000
# mean      3931.220288
# std       3985.918716
# min        326.000000
# 25%        951.000000
# 50%       2401.000000
# 75%       5324.000000
# max      18823.000000
# Name: price, dtype: float64

# %% [markdown]
# To show bar chat which diamad has clarity most

# %%
diamonds2.cut.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# To check the pair relation ship between the price,cut,carat,clarity

# %%
sb.pairplot(data = diamonds2, vars=['price','cut','carat','clarity'])
plt.show()

# %% [markdown]
# To check the corelation between the numarical  variables

# %%
sb.heatmap(diamonds2.corr(), annot=True, cmap = 'Reds')
plt.show()

# %% [markdown]
# Now  i am going to bulid a model for diamonds data set
# i found only 3 LR

# %%
R2_Scores = []
models = ['Linear Regression' , 'Lasso Regression','Ridge Regression']

# %%
label_cut = LabelEncoder()
label_color = LabelEncoder()
label_clarity = LabelEncoder()


diamonds2['cut'] = label_cut.fit_transform(diamonds2['cut'])
diamonds2['color'] = label_color.fit_transform(diamonds2['color'])
diamonds2['clarity'] = label_clarity.fit_transform(diamonds2['clarity'])

# %%
X = diamonds2.drop(['price'], axis=1)
y = diamonds2['price']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4, random_state=100)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV

# %%
linreg = LinearRegression()

# %%
clf_lr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_lr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_lr.predict(X_test)
print('Score :' % clf_lr.score(X_test, y_test))
print(accuracies)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)
print("Linear Regression Coefficients: \n")
print(clf_lr.coef_)
print("MSE:",mse)
print("MAE:",mae)
print("RMSE:",rmse)
print("R2:",r2)

R2_Scores.append(r2)
x_train = X_train
y_train_2 = y_train
x_train_1 = sm.add_constant(x_train)
model = sm.OLS(y_train_2, x_train_1)
results = model.fit()
print("summary",results.summary())
# Out:
# Score :
# [0.89245456 0.874547   0.89489332 0.88674894 0.88548009]
# Linear Regression Coefficients:
#
# [ 5372.698461      67.7144823   -449.18712424   492.16600246
#   -170.73471741  -206.74486008 -1061.30049319    83.71254895
#   -454.57902271]
# MSE: 1858905.3394512644
# MAE: 853.4118853259889
# RMSE: 1363.4167886054743
# R2: 0.8818241638747524
# summary                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.887
# Method:                 Least Squares   F-statistic:                 2.827e+04
# Date:                Mon, 23 Jan 2023   Prob (F-statistic):               0.00
# Time:                        13:37:41   Log-Likelihood:            -2.7814e+05
# No. Observations:               32265   AIC:                         5.563e+05
# Df Residuals:                   32255   BIC:                         5.564e+05
# ...

# %%
clf_la = Lasso(normalize=True)
clf_la.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_la, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_la.predict(X_test)
print('')
print('###### Lasso Regression ######')
print('Score : %.4f' % clf_la.score(X_test, y_test))
print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

print("Lasso Regression Coefficients: \n")
print(clf_la.coef_)

print('')
print('MSE     :%0.2f' % mse)
print('MAE    : %0.2f ' % mae)
print('RMSE   : %0.2f ' % rmse)
print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# ###### Lasso Regression ######
# Score : 0.8640
# [0.87632716 0.86475831 0.8773794  0.87190521 0.8684001 ]
# Lasso Regression Coefficients:
#
# [3626.00206976    0.         -166.08711136  300.97028395   -0.
#    -0.            0.            0.            0.        ]
#
# MSE     :2139016.54
# MAE    : 913.21
# RMSE   : 1462.54
# R2     : 0.86
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# ...

# %%
clf_rr = Ridge(normalize=True)
clf_rr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_rr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_rr.predict(X_test)

print('###### Ridge Regres')
print('Score : %.4f' % clf_rr.score(X_test, y_test))
print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

print("Ridge Regression Coefficients: \n")
print(clf_rr.coef_)

print('')
print('MSE    : %0.2f ' % mse)
print('MAE    : %0.2f ' % mae)
print('RMSE   : %0.2f ' % rmse)
print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# ###### Ridge Regres
# Score : 0.7837
# [0.78617761 0.79071441 0.79079187 0.79314046 0.7837636 ]
# Ridge Regression Coefficients:
#
# [876.06136871  47.17381156 -47.66799253 175.84488849 -43.17261223
#   -6.97145373 718.31455698 642.80781777 703.19138376]
#
# MSE    : 3403027.44
# MAE    : 1179.58
# RMSE   : 1844.73
# R2     : 0.78
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# ...

# %%
compare = pd.DataFrame({"algorithm":models , "R2_Scores":R2_Scores})
compare.sort_values(by='R2_Scores' ,ascending=False)
# Out:
#            algorithm  R2_Scores
# 0  Linear Regression   0.881824
# 1   Lasso Regression   0.864017
# 2   Ridge Regression   0.783660

# %% [markdown]
# So observing the above table linear regression has 88% accuracy so LR is good for this data

# %% [markdown]
# Now i am going to  answer the assignment 2  questions.

# %% [markdown]
# Q1. What are the features / variables in the data that actually affect my sourcing price in LR model ?

# %% [markdown]
# ans: Carat,Cut,Clarity ,Depth, Length ,Width,Height these are features affect on the data

# %% [markdown]
# Q2. How would you explain the sensitivity of the price to the variables in the LR model?

# %% [markdown]
# ans: by using the statistcall measure(R2) of propation of variance of the carat can be explained in terms of prices

# %% [markdown]
# Q3. Which metric to look up if Keerthi wants to know how good is the model fit and pls interpret it?

# %% [markdown]
# ans:By using the comparision  metric  after completing  done all model we can do it which model has more R2 value then she will interpret it

# %% [markdown]
# Q4. What is regularization and how has it helped to improve the model?

# %% [markdown]
# Regularization is type of regression,which helps to solve the overfiting problems.

# %% [markdown]
# Q5. Rerun the analysis with price as an independent variable along with the previous independent
# variables and see if you can predict the carat. (Provide your code + analysis of your results)

# %% [markdown]
# ans: the carat is a predict variable and price is independent variable.

# %%
X=diamonds2[['carat']]
X.head()
# Out:
#    carat
# 0   0.23
# 1   0.21
# 2   0.23
# 3   0.29
# 4   0.31

# %%
y=diamonds2.price
y.shape
# Out:
# (53775,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.4, random_state=66)

# %% [markdown]
# To create a instance of a LinearRegression class

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# To find the intercept and coefficent

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [7764.92579663]
# -2263.709254271719

# %%
y_pred = linreg.predict(X_test)
y_pred[:5]
# Out:
# array([3177.34050895, 7911.238077  , 6048.72100105, 1780.45270198,
#         461.16977318])

# %%
from sklearn import metrics

# Mean Absolute Error
print("Mean Absolute Error",metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error 996.4932279703562

# %%
print("Mean Squared Error",metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error 2329820.4032091913

# %%
# Root Mean Squared Error
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 1526.3749222288707

# %%
# %matplotlib inline
plt.scatter(X,y, color='red')
plt.plot(X, linreg.predict(X), color='blue')
plt.title('carat vs prices Training Set')
plt.xlabel('carat')
plt.ylabel('price')
plt.show()

# %%
from sklearn.model_selection import  cross_val_score
accuracies = cross_val_score(estimator = linreg, X = X_train, y = y_train, cv = 5,verbose = 1)
print(accuracies)
# Out:
# [0.84707043 0.85240959 0.84711376 0.84988828 0.84172346]
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %% [markdown]
# so it gives R2_Squares is [84%]

# %%
Thank YOu.
please provide feed back
